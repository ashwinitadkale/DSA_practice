# %% [markdown]
# Largest element in the array

# %%
#Brute Force
arr=[1,2,3,4,5,2,1]
arr.sort()
print(arr[-1])
# Out:
# 5

# %%
#Optimal Approach
arr=[1,2,3,4,5,2,1]
maxi=arr[0]
for i in range(len(arr)):
    if arr[i]>maxi:
        maxi=arr[i]
print(maxi)
# Out:
# 5

# %% [markdown]
# Second Largest element in the sorted array

# %%
arr=[1,2,3,4,5,2,1]
arr.sort()
print(arr[-2])
# Out:
# 4

# %%
# time O(n) space O(1)
def better_second(arr,n):
    n=len(arr)
    if n<2:
        return -1,-1
    smallest=min(arr)
    largest=max(arr)
    second_small=float('inf')
    second_large=float('-inf')
    for num in arr:
        if smallest<num<second_small:
            second_small=num
        if second_large<num<largest:
            second_large=num
    if second_small==float('inf'):
        second_small=-1
    if second_large==float('-inf'):
        second_large=-1
    return second_small,second_large
arr=[1,2,3,4,5,2,1]
better_second(arr,len(arr))
# Out:
# (2, 4)

# %% [markdown]
# Remove duplicates from sorted array

# %%
#time O(n) space O(n)
arr=[1,1,2,2,2,3,3]
arr_set=set(arr) 
print(list(arr_set))
# Out:
# [1, 2, 3]

# %%
#brute to remove duplicates time O(n) space O(n)
def remove_duplicates_brute(arr):
    unique=list(set(arr))
    for i in range(len(unique)):
        arr[i]=unique[i]
    return len(unique)
arr=[1,1,2,2,2,3,3]
k=remove_duplicates_brute(arr)
print(k)
print(arr[:k])
# Out:
# 3
# [1, 2, 3]

# %%
def remove_duplicates_better(arr):
    if len(arr)==0:
        return 0
    temp=[arr[0]]
    for i in range(1,len(arr)):
        if arr[i]!=arr[i-1]:
            temp.append(arr[i])
    for i in range(len(temp)):
        arr[i]=temp[i]
    return temp
arr = [1,1,2,2,2,3,3]
print(remove_duplicates_better(arr))
# Out:
# [1, 2, 3]

# %%
#Optimal Appraoch time : O(n) space: O(1)
def remove_duplicates_optimal(arr):
    if len(arr)==0:
        return 0
    i=0
    for j in range(1,len(arr)):
        if arr[i]!=arr[j]:
            i+=1
            arr[i]=arr[j]
    k=i+1
    return arr[:k]
arr=[1,1,2,2,2,3,3]
print(remove_duplicates_optimal(arr))
# Out:
# [1, 2, 3]

# %%
#Brute force
# nums=[3,0,1]
nums = [9,6,4,2,3,5,7,0,1]
nums.sort()
for i in range(len(nums)):
    if nums[i]!=i:
        print(i)
# Out:
# 8

# %%
#using Sum formula
nums = [9,6,4,2,3,5,7,0,1]
n=len(nums)
print(n*(n+1)//2-sum(nums))
# Out:
# 8

# %%
#Brute force
nums = [5,7,7,8,8,10] 
target=8 
ans=[]
for i in range(len(nums)):
    if nums[i]==target:
        ans.append(i)
print(ans)
# Out:
# [3, 4]

# %%
#using binary search
def position(nums,target):
    def first_occurrence():
        left,right=0,len(nums)-1
        ans=-1
        while left<=right:
            mid=(left+right)//2
            if nums[mid]==target:
                ans=mid
                right=mid-1
            elif nums[mid]<target:
                left=mid+1
            else:
                right=mid-1
        return ans
    def last_occurrence():
        left,right=0,len(nums)-1
        ans=-1
        while left<=right:
            mid=(left+right)//2
            if nums[mid]==target:
                ans=mid
                left=mid+1
            elif nums[mid]<target:
                left=mid+1
            else:
                right=mid-1
        return ans
    return [first_occurrence(),last_occurrence()]
        
nums = [5,7,7,8,8,10]
target=8
print(position(nums,target))
# Out:
# [3, 4]

# %% [markdown]
# Remove duplicates in-place from sorted array

# %%
#Brute force
arr=[1,1,2,2,2,3,3]
arr_set=set()
index=0
for num in arr:
    if num not in arr_set:
        arr_set.add(num)
        arr[index]=num
        index+=1
print(index)
print(arr[:index])
# Out:
# 3
# [1, 2, 3]

# %%
#Optimal Approach
arr=[1,1,2,2,2,3,3]
if not arr:
    print(0)
i=0
for j in range(1,len(arr)):
    if arr[j]!=arr[i]:
        i+=1
        arr[i]=arr[j]
print(i+1)
print(arr[:i+1])
# Out:
# 3
# [1, 2, 3]

# %% [markdown]
# Left rotate by one

# %%
#Brute Force
nums=[1,2,3,4,5]
n=len(nums)
temp=[0]*n
for i in range(1,n):
    temp[i-1]=nums[i]
temp[n-1]=nums[0]
# for num in temp:
#     print(num,end=' ')
print(temp)
# Out:
# [2, 3, 4, 5, 1]

# %%
#Optimal Appraoch
nums=[1,2,3,4,5]
n=len(nums)
temp=nums[0]
for i in range(1,n):
    nums[i-1]=nums[i]
nums[n-1]=temp
print(nums)
# Out:
# [2, 3, 4, 5, 1]

# %% [markdown]
# Rotate array by K elements

# %%
#Brute Force
def rotate(nums,k):
    n=len(nums)
    k=k%n
    for _ in range(k):
        last=nums[-1]
        for i in range(n-1,0,-1):
            nums[i]=nums[i-1]
        nums[0]=last
    return nums
nums=[1,2,3,4,5,6,7]
k=2
print(rotate(nums,k))
# Out:
# [6, 7, 1, 2, 3, 4, 5]

# %%
#Better Approach
def rotate(nums,k):
    n=len(nums)
    k=k%n
    temp=[0]*n
    for i in range(n):
        new_index=(i+k)%n
        temp[new_index]=nums[i]
    for i in range(n):
        nums[i]=temp[i]
    return nums
nums=[1,2,3,4,5,6,7]
k=2
print(rotate(nums,k))
# Out:
# [6, 7, 1, 2, 3, 4, 5]

# %%
#Optimal Approaclass Solution(object):

def reverse(self, nums, left, right):

    while left < right:

        nums[left], nums[right] = nums[right], nums[left]

        left += 1
        right -= 1


def rotate(self, nums, k):

    n = len(nums)

    k = k % n

        # Step 1
    self.reverse(nums, 0, n - 1)

        # Step 2
    self.reverse(nums, 0, k - 1)

        # Step 3
    self.reverse(nums, k, n - 1)

# %% [markdown]
# Valid anagram

# %%
s='racecar'
t='carrace'
if len(s)!=len(t):
    print(False)
temp=list(t)
for ch in s:
    if ch in temp:
        temp.remove(ch)
    else:
        print(False)
print(True)
# Out:
# True

# %% [markdown]
# Two Sum

# %%
#Brute force O(n2)
def twoSum(nums,target):
    for i in range(len(nums)):
        for j in range(i+1,len(nums)):
            if nums[i]+nums[j]==target and i!=j:
                return [i,j]

nums=[3,4,5,6]
target=10
print(twoSum(nums,target))
# Out:
# [1, 3]

# %%
#Better Approach O(N)
def twoSum(nums,target):
    hashmap={}
    for i in range(len(nums)):
        hashmap[nums[i]]=i
    for i in range(len(nums)):
        comp=target-nums[i]
        if comp in hashmap and hashmap[comp]!=i:
            return [i,hashmap[comp]]
nums=[3,4,5,6]
target=10
print(twoSum(nums,target))
# Out:
# [1, 3]

# %%
def twoSum(nums,target):
    hashmap={}
    for i in range(len(nums)):
        hashmap[nums[i]]=i
        comp=target-nums[i]
        if comp in hashmap and hashmap[comp]!=i:
            return [i,hashmap[comp]]
nums=[3,4,5,6]
target=10
print(twoSum(nums,target))
# Out:
# [3, 1]

# %%
# 2 pointer Greedy Approach
def twoSum(nums,target):
    n=len(nums)
    nums.sort()
    left,right=0,n-1
    while left<right:
        sum=nums[left]+nums[right]
        if sum==target:
            return [left,right]
        if sum<target:
            left+=1
        else:
            right-=1
    return [left,right]
nums=[3,4,5,6]
target=10
print(twoSum(nums,target))
# Out:
# [1, 3]

# %% [markdown]
# Majority Element

# %%
#Brute Force Approach time complexity O(n*n)
nums=[5,5,1,1,1,5,5]
n=len(nums)
for num in nums:
    if nums.count(num)>n//2:
        print(num)
        break
# Out:
# 5

# %%
#Better Approach using hashmap
nums=[5,5,1,1,1,5,5]
n=len(nums)
freq={}
for num in nums:
    freq[num]=freq.get(num,0)+1
for key,value in freq.items():
    if value>n//2:
        print(key)
    break
# Out:
# 5

# %%
#Optimal Approach O(n)
nums=[5,5,1,1,1,5,5]
n=len(nums)
count=0
candidate=None
for num in nums:
    if count==0:
        candidate=num
    if num==candidate:
        count+=1
    if num!=candidate:
        count-=1
print(candidate)
# Out:
# 5

# %% [markdown]
# THREE SUM

# %%
#Brute force t:O(n3) s:O(k)
def threeSum(nums):
    ans=set()
    n=len(nums)
    for i in range(n):
        for j in range(i+1,n):
            for k in range(j+1,n):
                if nums[i]+nums[j]+nums[k]==0:
                    triplet=tuple(sorted([nums[i],nums[j],nums[k]]))
                    ans.add(triplet)
    return list(ans)
print(threeSum([1,-1,0,2,3]))
# Out:
# [(-1, 0, 1)]

# %%
#Better Appraoch (hashset) t: O(n2) s: O(n)
def threeSum(nums):
    ans=set()
    n=len(nums)
    for i in range(n):
        seen=set()
        for j in range(i+1,n):
            third=-(nums[i]+nums[j])
            if third in seen:
                temp=sorted([nums[i],nums[j],third])
                ans.add(tuple(temp))
            seen.add(nums[j])
    return list(ans)
print(threeSum([1,-1,0,2,3,-1]))
# Out:
# [(-1, 0, 1), (-1, -1, 2)]

# %%
#optimal approach (2 pointer)
def threeSum(nums):
    nums.sort()
    result=[]
    n=len(nums)
    for i in range(n-2):
        if i>0 and nums[i]==nums[i-1]:
            continue
        left=i+1
        right=n-1
        while left<right:
            total=nums[i]+nums[left]+nums[right]
            if total<0:
                left+=1
            elif total>0:
                right-=1
            else:
                result.append([nums[i],nums[left],nums[right]])
                left+=1
                right-=1
                while left<right and nums[left]==nums[left-1]:
                    left+=1
                while left<right and nums[right]==nums[right+1]:
                    right-=1
    return result
print(threeSum([1,-1,0,2,3,-1]))
# Out:
# [[-1, -1, 2], [-1, 0, 1]]

# %%
#Group Anagram
def groupAnagram(strs):
    hashmap={}
    for word in strs:
        key=''.join(sorted(word))
        if key not in hashmap:
            hashmap[key]=[]
        hashmap[key].append(word)
    return list(hashmap.values())
strs = ["eat","tea","tan","ate","nat","bat"]
print(groupAnagram(strs))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %% [markdown]
# Top K frequent elements

# %%
#Optimal Approach
def topKFrequent(nums,k):
    freq={}
    for num in nums:
        freq[num]=freq.get(num,0)+1
    bucket=[[] for _ in range(len(nums)+1)]
    for num,count in freq.items():
        bucket[count].append(num)
    ans=[]
    for i in range(len(bucket)-1,-1,-1):
        for num in bucket[i]:
            ans.append(num)
            if len(ans)==k:
                return ans
nums=[1,1,1,2,2,3]
print(topKFrequent(nums,2))
# Out:
# [1, 2]
